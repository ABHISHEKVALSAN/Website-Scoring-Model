# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfr=pd.read_csv('tempSiteRatings.csv')
dfd=pd.read_csv('tempUrlMetrics.csv')

# %%
dfd['rating']=dfr['rating']
dfd.drop(['slno','url'],1,inplace=True)
dfd.to_csv('data.csv')

# %%
data=pd.read_csv('data.csv')
#data

# %%
data.drop(['Unnamed: 0'],1, inplace=True)
data.drop(['p3'],1, inplace=True)

# %%
correlation = data.corr(method='pearson')
columns = correlation.nlargest(13,'rating').index
columns
#np.sort(columns)
# Out:
# Index(['rating', 'p9', 'p7', 'p13', 'p2', 'p8', 'p10', 'p6', 'p1', 'p4', 'p12',
#        'p5'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(10,10))    
correlation_map = np.corrcoef(data[columns].values.T)
sns.set(font_scale=1)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f',yticklabels=columns.values, xticklabels=columns.values)
plt.savefig('corr.png')
#plt.show()

# %%
Y=data['rating'].values
X_temp=data[columns]
X_temp.drop(['rating'],1, inplace=True)
X=X_temp.values

# %%
for i in range(13):
    #X[:,i]=X[:,i]/(X[:,i].max()-X[:,i].min())
    print(X[:,i])
# Out:
# [ 18. 111.  78.  20.  92.  34.  55.  27. 724.  47.  22. 129.   3. 146.
#   43.  53.  48. 111.  53.  41. 111.   0.  32.  74. 106.  45.  57.  60.
#   78. 146.  48.  45.  54.  42.  58. 154.  25.  75. 139.  15.  48.  49.
#   25.  25.  42.  11.  42.  89. 148. 241. 153.  42.  64. 100. 137. 137.
#   35.  75.   0.  58.  36. 106.  97.  74.  63.  38.  78. 115.  97.  76.
#  190.  39. 243. 129. 152.  73.  82.  67. 114. 138.  24.  80.  32.  88.
#   88. 186.  56.  89.  73.  72. 154. 268. 104.  96.]
# [1.00797363e+03 2.99456250e+03 2.74051270e+03 2.76881836e+02
#  9.87582031e+02 9.04706641e+03 3.01752637e+03 1.70064453e+02
#  1.44549609e+03 7.32768555e+02 2.63095801e+03 2.48219727e+02
#  7.51699219e+01 3.35362305e+02 4.35715684e+04 4.60301758e+02
#  1.51925391e+03 1.37965820e+03 5.63607715e+03 2.83767969e+03
#  1.35975195e+03 1.10732422e+01 1.68529297e+02 7.04435547e+02
#  4.06869141e+02 6.51744141e+02 1.34852246e+03 3.03932422e+03
#  1.75399707e+03 1.10384473e+03 1.04686523e+03 4.47014453e+03
#  1.62780371e+03 2.91251953e+02 9.04961914e+02 9.32644531e+02
#  1.90754980e+03 1.09579102e+03 3.79765625e+02 1.02663223e+04
#  4.62310059e+03 1.81952344e+03 2.96973633e+02 2.12260742e+02
#  1.47258594e+03 2.85869141e+01 1.88502930e+03 1.13451172e+03
#  1.82121094e+03 3.94834473e+03 6.81526172e+03 2.91758789e+02
#  1.27456250e+03 5.80680371e+03 1.09575195e+02 2.43622754e+03
#  9.29194336e+02 2.20677734e+02 4.80468750e-01 2.20833691e+03

# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-818-321d422009ee> in <module>
#       1 for i in range(13):
#       2     #X[:,i]=X[:,i]/(X[:,i].max()-X[:,i].min())
# ----> 3     print(X[:,i])
#
# IndexError: index 11 is out of bounds for axis 1 with size 11

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, shuffle='True',test_size=0.25, random_state=1)

# %%
def LinearReg():
    from sklearn.linear_model import LinearRegression
    reg =LinearRegression()
    return reg
def RidgeReg():
    from sklearn.linear_model import Ridge
    reg =Ridge()
    return reg
def ABReg():
    from sklearn.ensemble import AdaBoostRegressor
    reg=AdaBoostRegressor(random_state=0, n_estimators=100)
    return reg
def DTReg():
    from sklearn.tree import DecisionTreeRegressor
    reg=DecisionTreeRegressor(random_state=0)
    return reg
def MLPReg():
    from sklearn.neural_network import MLPRegressor
    reg=MLPRegressor(hidden_layer_sizes=(4,),activation='logistic',solver='adam', max_iter=10000,batch_size=10,)
    return reg
def LogReg():
    from sklearn.linear_model import LogisticRegression
    reg=LogisticRegression()
    return reg
def XBReg():
    import xgboost as xgb
    reg=xgb.XGBRegressor(objective ='reg:linear', colsample_bytree = 0.3, learning_rate = 0.1,max_depth = 5, alpha = 10, n_estimators = 10)
    return reg
def RMS_test(reg):
    from sklearn.metrics import mean_squared_error
    Y_pred=reg.predict(X_test)
    return mean_squared_error(Y_test, Y_pred)
def RMS_train(reg):
    from sklearn.metrics import mean_squared_error
    Y_pred=reg.predict(X_train)
    return mean_squared_error(Y_train, Y_pred)

# %%
regLinear=LinearReg()
regLinear.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
regRidge=RidgeReg()
regRidge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
regAB=ABReg()
regAB.fit(X_train,Y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#          n_estimators=100, random_state=0)

# %%
regDT=DTReg()
regDT.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
regMLP=MLPReg()
regMLP.fit(X_train,Y_train)
# Out:
# MLPRegressor(activation='logistic', alpha=0.0001, batch_size=10, beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(4,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=10000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
regLog=LogReg()
regLog.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
test=[RMS_test(regLinear),RMS_test(regRidge),RMS_test(regAB),RMS_test(regDT),RMS_test(regMLP),RMS_test(regLog)]
train=[RMS_train(regLinear),RMS_train(regRidge),RMS_train(regAB),RMS_train(regDT),RMS_train(regMLP),RMS_train(regLog)]

# %%
for i in zip(test,train):
    print(i)
# Out:
# (0.045421033363784176, 0.04979928401476582)
# (0.0446832441032263, 0.04980647804607064)
# (0.08333333333333333, 0.0)
# (0.08333333333333333, 0.0)
# (0.04107128441628797, 0.05126473683964187)
# (0.041666666666666664, 0.05714285714285714)

# %%
regLog.coef_
# Out:
# array([[0.95495267, 0.28579136, 0.33428297, 0.05367191]])

# %%
regLinear.coef_
# Out:
# array([0.04532214, 0.04718882, 0.00741622, 0.06018129])
